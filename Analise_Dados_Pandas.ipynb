# %% [markdown]
# <a href="https://colab.research.google.com/github/IsadoraPrevitalle/TAR/blob/Introdu%C3%A7%C3%A3o/Analise_Dados_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Verificando os campos de maiores reportagens de roubos de identidades por idade, números de relatórios e tipo de roubos, para comparar com nossa base de publico usuarios de nosso serviço por faixa etária

# %%
pd.read_csv('Relatórios de roubo de identidade por idade.csv', usecols = ['Identity Theft Reports by Age','Unnamed: 1'
,'IDT Theft Type by Age','Unnamed: 5','Unnamed: 6'])
#Identity Theft Reports by Age - Relatórios de roubo de identidade por idade
#Age Range - faixa etária
#Of Reports - Quantidade de relatórios
#Theft Type	- Tipo de roubo
# Out:
#                         Identity Theft Reports by Age    Unnamed: 1  \
# 0                                                 NaN           NaN
# 1                                           Age Range  # of Reports
# 2                                        19 and Under        13,852
# 3                                             20 - 29        61,114
# 4                                             30 - 39        80,467
# ..                                                ...           ...
# 56                                                NaN           NaN
# 57                                                NaN           NaN
# 58                                                NaN           NaN
# 59                                                NaN           NaN
# 60  Source: Consumer Sentinel Network Data Book 20...           NaN
#
#    IDT Theft Type by Age                       Unnamed: 5    Unnamed: 6
# 0                    NaN                              NaN           NaN
# ...

# %% [markdown]
# Verificando os 31 primeiros registros de roubo de identidade por tipo em 5 estados diferentes para tirar uma media por localidade

# %%
pd.read_csv('Categorias de fraude por valor perdido.csv')
#Aqui temos o grafico completo com varios setores de categorias sobre fraudes, par nós as linhas 5,6 e 9 são as mais interessantes por trabalhar com dados de investimentos, oprtunidades de emprego e serviços pela internet
# Out:
#                 Fraud Categories by Total Amount Lost    Unnamed: 1  \
# 0                                                 NaN           NaN
# 1                                            Category  Total $ Loss
# 2                                      Imposter Scams  $328,423,263
# 3                   Prizes, Sweepstakes and Lotteries   $95,052,359
# 4                      Shop-at-Home and Catalog Sales   $94,117,967
# 5                                  Investment Related   $47,697,104
# 6                      Business and Job Opportunities   $46,914,979
# 7               Travel, Vacations and Timeshare Plans   $38,454,908
# 8    Foreign Money Offers and Counterfeit Check Scams   $34,343,296
# 9                                   Internet Services   $19,397,434
# 10    Mortgage Foreclosure Relief and Debt Management   $17,179,967
# 11                      Telephone and Mobile Services   $16,920,319
# 12               Advance Payments for Credit Services   $14,904,565
# ...

# %%
VP = pd.read_csv('Categorias de fraude por valor perdido.csv')
VP.iloc [5]
# Investment Related - Relacionado a investimentos
#total e media de perdas, quantidade de reportagens e quantidade de reportagens em porcentagem, Método de contato principal por categoria e Principal método de pagamento por categoria
# Out:
# Fraud Categories by Total Amount Lost            Investment Related
# Unnamed: 1                                              $47,697,104
# Unnamed: 2                                                    $400
# Unnamed: 3                                                  15,079
# Unnamed: 4                                                      46%
# Unnamed: 5                               Consumer Initiated Contact
# Unnamed: 6                                            Wire Transfer
# Name: 5, dtype: object

# %%
VP = pd.read_csv('Categorias de fraude por valor perdido.csv')
VP.iloc [6]
#Business and Job Opportunities = Oportunidades de emprego
#total e media de perdas, quantidade de reportagens e quantidade de reportagens em porcentagem, Método de contato principal por categoria e Principal método de pagamento por categoria
# Out:
# Fraud Categories by Total Amount Lost    Business and Job Opportunities
# Unnamed: 1                                                  $46,914,979
# Unnamed: 2                                                      $1,063
# Unnamed: 3                                                      18,702
# Unnamed: 4                                                          34%
# Unnamed: 5                                                        Email
# Unnamed: 6                                                Wire Transfer
# Name: 6, dtype: object

# %%
VP = pd.read_csv('Categorias de fraude por valor perdido.csv')
VP.iloc [9]
#Serviços por internet
#total e media de perdas, quantidade de reportagens e quantidade de reportagens em porcentagem, Método de contato principal por categoria e Principal método de pagamento por categoria
# Out:
# Fraud Categories by Total Amount Lost             Internet Services
# Unnamed: 1                                              $19,397,434
# Unnamed: 2                                                    $183
# Unnamed: 3                                                  45,093
# Unnamed: 4                                                      14%
# Unnamed: 5                               Consumer Initiated Contact
# Unnamed: 6                                              Credit Card
# Name: 9, dtype: object

# %% [markdown]
# Verificando os três principais reatórios de roubo de identidade por ano, de acordo com o ano e as contagens de reclamações para verificar o crescimento anual

# %%
pd.read_csv('Contagem de relatórios.csv')
#Complaint Count - Contagem de reclamações
# Out:
#    Number of Fraud, Identity Theft and Other Reports by Year\n    Unnamed: 1
# 0                                                 NaN                    NaN
# 1                                                Year           # of Reports
# 2                                                2001                325,519
# 3                                                2002                551,622
# 4                                                2003                713,657
# 5                                                2004                860,383
# 6                                                2005                909,314
# 7                                                2006                906,129
# 8                                                2007              1,070,447
# 9                                                2008              1,261,124
# 10                                               2009              1,428,977
# ...
